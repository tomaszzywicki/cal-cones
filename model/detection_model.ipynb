# %%
import os
import sys
import torch
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from yolo_model import train_model, predict_images

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"[INFO] Using device: {device}")
# Out:
# [INFO] Using device: cuda

# %% [markdown]
# ### Detection model version 3

# %%
train_model(model_path="data/dataset_v3/yolo11s.pt" ,
            data_yaml="data/dataset_v3/yolo_det_v3.yaml",
            epochs=50,
            img_size=640,
            batch_size=16,
            device=device,
            train_name="yolo_det_v3")
# Out:
# [INFO] Starting training...
# Ultralytics 8.3.227  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...

# %% [markdown]
# ### Detection model version 4

# %%
train_model(model_path="data/dataset_v4/yolo11m.pt" ,
            data_yaml="data/dataset_v4/yolo_det_v4.yaml",
            epochs=50,
            img_size=640,
            batch_size=16,
            device=device,
            train_name="yolo_det_v4")
# Out:
# [INFO] Starting training...
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...

# %% [markdown]
# ### YOLO S on dataset v4

# %%
train_model(model_path="data/dataset_v4/yolo11s.pt" ,
            data_yaml="data/dataset_v4/yolo_det_v4.yaml",
            epochs=100,
            img_size=640,
            batch_size=16,
            device=device,
            train_name="yolo_det_v4_s")
# Out:
# [INFO] Starting training...
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...

# %% [markdown]
# ### YOLO M on dataset v4 (continuation for 50 more epochs)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

model = YOLO("data/dataset_v4/yolo11m.pt").load("runs/detect/yolo_det_v4/weights/last.pt")
model.to(device)

results = model.train(data="data/dataset_v4/yolo_det_v4.yaml",
                      epochs=50,
                      imgsz=640,
                      batch=16,
                      device=device,
                      name="yolo_det_v4_m")
# Out:
# Using device: cuda
# Transferred 643/649 items from pretrained weights
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...

# %% [markdown]
# ### YOLO medium (100 epochs, parameters tweaking)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"[INFO] Using device: {device}")

model = YOLO("data/dataset_v4/yolo11m.pt")
model.to(device)

results = model.train(
            data="data/dataset_v4/yolo_det_v4.yaml",
            epochs=100,
            imgsz=768,
            rect=True,
            # multi_scale=True,
            batch=0.8,
            device=device,
            box=6.0,
            cls=1.0,
            name="yolo_det_v4_iter5")
# Out:
# [INFO] Using device: cuda
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...
