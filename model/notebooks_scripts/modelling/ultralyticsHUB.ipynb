# %% [markdown]
# # MEAT

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/OnM7Pdi8IoFZ3CQxtor4')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 715.5/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/OnM7Pdi8IoFZ3CQxtor4
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # VEGETABLES

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/0tTYWKN3j6PMMetES7Ya')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 709.8/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/0tTYWKN3j6PMMetES7Ya
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # FRUIT

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/5kipXCHuUjvtNb8awu1V')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 715.9/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/5kipXCHuUjvtNb8awu1V
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # BREAD-PASTA-GRAINS

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/ZJ8CPh3TXj2qDh1ZIZ57')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 715.7/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/ZJ8CPh3TXj2qDh1ZIZ57
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# ### NUTS-SEEDS

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/uFfGSGv8OynF5YF3a3Cu')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 713.5/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/uFfGSGv8OynF5YF3a3Cu
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # CHEESE-DAIRY

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/zf7lsBblhJXCd3NwRQzI')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 713.6/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/zf7lsBblhJXCd3NwRQzI
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # MISC

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/c7tCKRSCxFZpn6gYLKp6')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 714.0/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/c7tCKRSCxFZpn6gYLKp6
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # MISC FIXED

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/pvNU93qRZ1xRN1WRsTRd')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 794.8/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/pvNU93qRZ1xRN1WRsTRd
# New https://pypi.org/project/ultralytics/8.3.235 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # VEGETABLE v2

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/aCSgdAkzDMNKJ4B2MeJ1')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 804.1/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/aCSgdAkzDMNKJ4B2MeJ1
# New https://pypi.org/project/ultralytics/8.3.235 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # FRUIT v2

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/E2iirOm2rkEv2SDi4X5W')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 804.0/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/E2iirOm2rkEv2SDi4X5W
# New https://pypi.org/project/ultralytics/8.3.235 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %% [markdown]
# # BREAD-PASTA-GRAINS v2

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('dac9c25ccae9488bc73e47649116d120c5d958e0ec')

model = YOLO('https://hub.ultralytics.com/models/E5VEdCaewbnrVeqCeQpg')
results = model.train()
# Out:
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 804.0/930.2 GB disk)
# Ultralytics HUB: New authentication successful
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/E5VEdCaewbnrVeqCeQpg
# New https://pypi.org/project/ultralytics/8.3.235 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
